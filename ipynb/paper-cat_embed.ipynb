# %%
import pandas as pd, numpy as np
import os, json
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as torch_data
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
os.getcwd()
from sentence_transformers import SentenceTransformer

# %%
TRAIN_RATIO = 0.7
VALID_RATIO = 0.2
TEST_RATIO = 1 - (TRAIN_RATIO + VALID_RATIO)

WINDOW_SIZE = 168
HORIZON = 6
NORM_METHOD = 'z_score'
DATASET = 'Houston'
START_POI = 0
END_POI = 400
BATCH_SIZE = 1
TOTAL_DAYS = 400

CAT_COLS = ['top_category', 'sub_category']

RESULT_TRAIN_FILE = f'output/{DATASET}/train_{START_POI}_{END_POI}'

# %%
df = pd.read_pickle(f'./cache_data/data-{START_POI}-{END_POI}-{TOTAL_DAYS}-{DATASET}.pkl')
df['phone_number'] = df['phone_number'].fillna(0)
df['postal_code'] = df['postal_code'].fillna(0)
df['phone_number'] = df['phone_number'].astype(int)
df['postal_code'] = df['postal_code'].astype(int)
# Create sentences for each POI using as many columns as possible
sentences = []
# replace all nan values in columns 'location_name', 'street_address, 'city', 'region', 'postal_code', 'open_hours', 'phone_number', 'top_category', 'sub_category' with "unknown"
columns_to_fill = ['location_name', 'street_address', 'city', 'region', 'postal_code', 'open_hours', 'phone_number', 'top_category', 'sub_category']
for col in columns_to_fill:
    df[col] = df[col].fillna('unknown')
    if col == 'phone_number' or col == 'postal_code':
        df[col] = df[col].replace(0, 'unknown')
# create a sentence description for each POI
for index, row in df.iterrows():
    poi_details = f"This point of interest is {row['location_name']} located at {row['street_address']}, {row['city']}, {row['region']}, {row['postal_code']}. It is open for business during {row['open_hours']} and can be contacted by phone at {row['phone_number']}. This location belongs to the top category {row['top_category']}, with sub-category {row['sub_category']}."
    poi_details = poi_details.replace('unknown, unknown, unknown, unknown', 'unknown')
    # add sentences to the list
    sentences.append(poi_details)
    if index >= END_POI - START_POI - 1:
        break
# create a sentence description for each meta-node
for index, row in df.iloc[END_POI - START_POI:len(df)].iterrows():
    if row['top_category'] == 'Global':
        # meta-node represents all POIs in a city
        meta_node_details = f"This is the meta node that represents all the points of interests in {df.loc[0, 'city']}."
    else:
        # meta-node represents a category in a city
        meta_node_details = f"This is the meta node that represents all the points of interests in {df.loc[0, 'city']} that belong to the category {row['top_category']}."
    sentences.append(meta_node_details)
sentences
# Out:
# ['This point of interest is George Bush Intercontinental Airport located at 2800 N Terminal Rd, Houston, TX, 77032. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Support Activities for Air Transportation, with sub-category Other Airport Operations.',
#  'This point of interest is American Express Centurion Lounge located at 2800 N Terminal Rd Terminal D, Houston, TX, 77032. It is open for business during { "Mon": [["5:30", "21:00"]], "Tue": [["5:30", "21:00"]], "Wed": [["5:30", "21:00"]], "Thu": [["5:30", "21:00"]], "Fri": [["5:30", "21:00"]], "Sat": [["5:30", "21:00"]], "Sun": [["5:30", "21:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Gasoline Stations, with sub-category Gasoline Stations with Convenience Stores.',
#  'This point of interest is Simon mall located at 5085 Westheimer Rd, Houston, TX, 77056. It is open for business during { "Mon": [["10:00", "19:00"]], "Tue": [["10:00", "19:00"]], "Wed": [["10:00", "19:00"]], "Thu": [["10:00", "19:00"]], "Fri": [["10:00", "18:00"]], "Sat": [["10:00", "17:00"]], "Sun": [] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is George Bush Intercontinental Airport Terminal E located at 3950 S Terminal Terminal E, Houston, TX, 77066. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Traveler Accommodation, with sub-category Hotels (except Casino Hotels) and Motels.',
#  'This point of interest is William P Hobby Airport located at 7800 Airport Blvd, Houston, TX, 77061. It is open for business during unknown and can be contacted by phone at 17136403000. This location belongs to the top category Support Activities for Air Transportation, with sub-category Other Airport Operations.',
#  'This point of interest is Bally Fitness Center Shopping Center located at 9801 Katy Fwy, Houston, TX, 77024. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is William P Hobby Airport Terminal 2 located at 7800 Airport Blvd, Houston, TX, 77061. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Support Activities for Air Transportation, with sub-category Other Airport Operations.',
#  'This point of interest is George Bush Intercontinental Airport Terminal A located at 2800 N Terminal Rd, Houston, TX, 77032. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Support Activities for Air Transportation, with sub-category Other Airport Operations.',
#  'This point of interest is Pediatric Education And Creative Arts Program located at 1515 Holcombe Blvd Unit 87, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is George Bush Intercontinental Airport Terminal E located at 2800 N Terminal Rd, Houston, TX, 77032. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Support Activities for Air Transportation, with sub-category Other Airport Operations.',
#  'This point of interest is George Bush Intercontinental Airport Terminal B located at 2800 N Terminal Rd, Houston, TX, 77032. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Support Activities for Air Transportation, with sub-category Other Airport Operations.',
#  'This point of interest is Village Plaza At Bunker Hill located at 9710 Katy Fwy, Houston, TX, 77055. It is open for business during { "Mon": [["9:00", "19:00"]], "Tue": [["9:00", "19:00"]], "Wed": [["9:00", "19:00"]], "Thu": [["9:00", "19:00"]], "Fri": [["9:00", "19:00"]], "Sat": [["9:00", "17:00"]], "Sun": [] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Citycentre Houston located at 800 Town and Country Blvd, Houston, TX, 77024. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Meyerland Plaza located at 4700 Beechnut St, Houston, TX, 77096. It is open for business during { "Mon": [["9:00", "16:00"]], "Tue": [["9:00", "16:00"]], "Wed": [], "Thu": [["9:00", "16:00"]], "Fri": [["9:00", "16:00"]], "Sat": [["9:00", "18:00"]], "Sun": [] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Houston Astrodome located at 8400 Kirby Dr, Houston, TX, 77054. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Museums, Historical Sites, and Similar Institutions, with sub-category Historical Sites.',
#  'This point of interest is Minute Maid Park located at 501 Crawford St, Houston, TX, 77002. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Spectator Sports, with sub-category Sports Teams and Clubs.',
#  'This point of interest is Houston Methodist Hospital located at 6565 Fannin St, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category General Medical and Surgical Hospitals, with sub-category General Medical and Surgical Hospitals.',
#  'This point of interest is University Of Houston System Administration located at 212 Ezekiel Cullen Building, Houston, TX, 77204. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Educational Support Services, with sub-category Educational Support Services.',
#  'This point of interest is Shops At Copper Crossing The located at 16255 FM 52, Houston, TX, 77095. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Vintage Park located at 110 Vintage Park Blvd, Houston, TX, 77070. It is open for business during { "Mon": [["9:00", "17:00"]], "Tue": [["9:00", "17:00"]], "Wed": [["9:00", "17:00"]], "Thu": [["9:00", "17:00"]], "Fri": [["9:00", "17:00"]], "Sat": [["9:00", "17:00"]], "Sun": [["9:00", "17:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is The Marketplace located at 6565 Fannin St Methodists Hospital, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Restaurants and Other Eating Places, with sub-category Full-Service Restaurants.',
#  'This point of interest is Oxford Plaza located at 10407 North, Houston, TX, 77037. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Chick-fil-A located at 1515 Holcombe Blvd, Houston, TX, 77030. It is open for business during { "Mon": [["6:30", "22:00"]], "Tue": [["6:30", "22:00"]], "Wed": [["6:30", "22:00"]], "Thu": [["6:30", "22:00"]], "Fri": [["6:30", "22:00"]], "Sat": [["6:30", "22:00"]], "Sun": [] } and can be contacted by phone at 17137922646. This location belongs to the top category Restaurants and Other Eating Places, with sub-category Limited-Service Restaurants.',
#  'This point of interest is Washington Heights located at 111 Yale St, Houston, TX, 77007. It is open for business during { "Mon": [["8:00", "20:00"]], "Tue": [["8:00", "20:00"]], "Wed": [["8:00", "20:00"]], "Thu": [["8:00", "20:00"]], "Fri": [["8:00", "20:00"]], "Sat": [["8:00", "17:00"]], "Sun": [["8:00", "17:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Copperfield Shopping Center located at 6565 Highway 6 N, Houston, TX, 77084. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category unknown, with sub-category unknown.',
#  'This point of interest is Smoothie King located at 1515 Holcombe Blvd. Dining Services, Houston, TX, 77030. It is open for business during { "Mon": [["7:00", "21:00"]], "Tue": [["7:00", "21:00"]], "Wed": [["7:00", "21:00"]], "Thu": [["7:00", "21:00"]], "Fri": [["7:00", "21:00"]], "Sat": [["9:00", "21:00"]], "Sun": [["11:00", "19:00"]] } and can be contacted by phone at 17137927162. This location belongs to the top category Restaurants and Other Eating Places, with sub-category Snack and Nonalcoholic Beverage Bars.',
#  'This point of interest is University Of Houston located at 212 E Cullen Building, Houston, TX, 77204. It is open for business during { "Mon": [["7:00", "18:00"]], "Tue": [["7:00", "18:00"]], "Wed": [["7:00", "18:00"]], "Thu": [["7:00", "18:00"]], "Fri": [["7:00", "18:00"]], "Sat": [], "Sun": [] } and can be contacted by phone at unknown. This location belongs to the top category Colleges, Universities, and Professional Schools, with sub-category Colleges, Universities, and Professional Schools.',
#  'This point of interest is Commons At Willowbrook The located at 7502 Cypress Creek Pkwy # 7950, Houston, TX, 77070. It is open for business during unknown and can be contacted by phone at 17139003006. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Methodist Hospital The located at 6565 Fannin St, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category General Medical and Surgical Hospitals, with sub-category General Medical and Surgical Hospitals.',
#  'This point of interest is Eldridge Parkway Village located at 12355 FM 1960 Rd W, Houston, TX, 77065. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Houston Methodist Willowbrook Hospital located at 18220 State Highway 249, Houston, TX, 77070. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category General Medical and Surgical Hospitals, with sub-category General Medical and Surgical Hospitals.',
#  'This point of interest is Memorial H S located at 935 Echo Ln, Houston, TX, 77024. It is open for business during unknown and can be contacted by phone at 17132512500. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is Marq e Center located at 7620 Katy Fwy, Houston, TX, 77024. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Town & Country Village located at 12850 Memorial Dr, Houston, TX, 77024. It is open for business during { "Mon": [["10:00", "18:00"]], "Tue": [["10:00", "18:00"]], "Wed": [["10:00", "18:00"]], "Thu": [["10:00", "19:00"]], "Fri": [["10:00", "19:00"]], "Sat": [["10:00", "18:00"]], "Sun": [["12:00", "17:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Rice University located at 6100 Main St, Houston, TX, 77005. It is open for business during { "Mon": [["8:00", "17:00"]], "Tue": [["8:00", "17:00"]], "Wed": [["8:00", "17:00"]], "Thu": [["8:00", "17:00"]], "Fri": [["8:00", "17:00"]], "Sat": [], "Sun": [] } and can be contacted by phone at unknown. This location belongs to the top category Colleges, Universities, and Professional Schools, with sub-category Colleges, Universities, and Professional Schools.',
#  'This point of interest is Shops At Stone Park located at 5810 E Sam Houston Pkwy N, Houston, TX, 77049. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Bertner Avenue Cafe located at 6720 Bertner Ave St. Lukes Hospital, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Restaurants and Other Eating Places, with sub-category Full-Service Restaurants.',
#  'This point of interest is Elmsworth Center located at 9370 W Sam Houston Pkwy S # 9380, Houston, TX, 77099. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Michael E Debakey Va Medical Center located at Michael E. Debakey Va Medical Center, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Colleges, Universities, and Professional Schools, with sub-category Colleges, Universities, and Professional Schools.',
#  'This point of interest is Houston Methodist West Hospital located at 18500 Katy Fwy, Houston, TX, 77094. It is open for business during { "Mon": [["7:30", "18:00"]], "Tue": [["7:30", "18:00"]], "Wed": [["7:30", "18:00"]], "Thu": [["7:30", "18:00"]], "Fri": [["7:30", "18:00"]], "Sat": [], "Sun": [] } and can be contacted by phone at unknown. This location belongs to the top category General Medical and Surgical Hospitals, with sub-category General Medical and Surgical Hospitals.',
#  'This point of interest is Market At Eldridge Parkway located at 2706 Eldridge Pkwy, Houston, TX, 77082. It is open for business during unknown and can be contacted by phone at 12814774381. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is George R Brown Convention Center located at 1001 Avenida de las Americas, Houston, TX, 77010. It is open for business during { "Mon": [["8:00", "17:00"]], "Tue": [["8:00", "17:00"]], "Wed": [["8:00", "17:00"]], "Thu": [["8:00", "17:00"]], "Fri": [["8:00", "17:00"]], "Sat": [], "Sun": [] } and can be contacted by phone at 17138538000. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Tomball Crossing located at 22545 Highway 249, Houston, TX, 77377. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category unknown, with sub-category unknown.',
#  'This point of interest is Dun Huang Plaza 敦煌廣場 located at 9889 Bellaire Blvd, Houston, TX, 77036. It is open for business during { "Mon": [["10:00", "24:00"]], "Tue": [["10:00", "24:00"]], "Wed": [["10:00", "24:00"]], "Thu": [["10:00", "24:00"]], "Fri": [["10:00", "24:00"]], "Sat": [["10:00", "24:00"]], "Sun": [["10:00", "24:00"]] } and can be contacted by phone at 17139818803. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Walmart located at 5655 E Sam Houston Pkwy N, Houston, TX, 77015. It is open for business during { "Mon": [["7:00", "19:00"]], "Tue": [["7:00", "19:00"]], "Wed": [["7:00", "19:00"]], "Thu": [["7:00", "19:00"]], "Fri": [["7:00", "19:00"]], "Sat": [["7:00", "19:00"]], "Sun": [["8:00", "18:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Walmart located at 15955 FM 529 Rd, Houston, TX, 77095. It is open for business during { "Mon": [["9:00", "20:00"]], "Tue": [["9:00", "20:00"]], "Wed": [["9:00", "20:00"]], "Thu": [["9:00", "20:00"]], "Fri": [["9:00", "20:00"]], "Sat": [["9:00", "20:00"]], "Sun": [["12:00", "17:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Sawyer Heights Village located at 1901 Taylor St, Houston, TX, 77007. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Willowbrook Plaza located at 17355 State Highway 249, Houston, TX, 77064. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Houston Christian High School located at 2700 W Sam Houston Pkwy N, Houston, TX, 77043. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is Clear Lake Marketplace located at 3501 Clear Lake City Blvd, Houston, TX, 77059. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Coffee Corner located at 6651 Main St, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Restaurants and Other Eating Places, with sub-category Snack and Nonalcoholic Beverage Bars.',
#  'This point of interest is Langham Creek H S located at 17610 FM 529 Rd, Houston, TX, 77095. It is open for business during unknown and can be contacted by phone at 12814635400. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is Northwest Crossing Centre located at 13238 Northwest, Houston, TX, 77040. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Lone Star College System Lone Star College University Park located at 20515 Sh 249 Sh 249 And Louetta Road, Houston, TX, 77070. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Junior Colleges, with sub-category Junior Colleges.',
#  'This point of interest is Greenway Commons located at 3830 Richmond Ave, Houston, TX, 77027. It is open for business during unknown and can be contacted by phone at 18328366089. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Shops At Highland Village The located at 4055 Westheimer Rd, Houston, TX, 77027. It is open for business during { "Mon": [["10:00", "21:00"]], "Tue": [["10:00", "21:00"]], "Wed": [["10:00", "21:00"]], "Thu": [["10:00", "21:00"]], "Fri": [["10:00", "21:00"]], "Sat": [["10:00", "19:00"]], "Sun": [["12:00", "18:00"]] } and can be contacted by phone at 17138503100. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Easton Commons located at 8500 Highway 6 N, Houston, TX, 77095. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Cypress Falls H S located at 9811 Huffmeister Rd, Houston, TX, 77095. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is Hedwig Village located at 9401 Katy Fwy # 9453, Houston, TX, 77024. It is open for business during { "Mon": [["10:00", "20:00"]], "Tue": [["10:00", "20:00"]], "Wed": [["10:00", "20:00"]], "Thu": [["10:00", "20:00"]], "Fri": [["10:00", "20:00"]], "Sat": [["10:00", "21:00"]], "Sun": [["11:00", "19:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is San Jacinto Community College South Campus located at 13735 Beamer Rd, Houston, TX, 77089. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Junior Colleges, with sub-category Junior Colleges.',
#  'This point of interest is Walmart located at 3450 Cypress Creek Pkwy, Houston, TX, 77068. It is open for business during { "Mon": [["10:00", "19:00"]], "Tue": [["10:00", "19:00"]], "Wed": [["10:00", "19:00"]], "Thu": [["10:00", "19:00"]], "Fri": [["10:00", "19:00"]], "Sat": [["10:00", "19:00"]], "Sun": [["10:00", "19:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Cypress Creek H S located at 9815 Grant Rd, Houston, TX, 77070. It is open for business during unknown and can be contacted by phone at 12818974200. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is Westgate Marketplace located at 1330 Fry Rd # 1500, Houston, TX, 77084. It is open for business during unknown and can be contacted by phone at 18327647411. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Memorial Park located at Memorial Park, Houston, TX, 77007. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Museums, Historical Sites, and Similar Institutions, with sub-category Nature Parks and Other Similar Institutions.',
#  'This point of interest is Memorial Hermann located at 6411 Fannin St, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Offices of Physicians, with sub-category Offices of Physicians (except Mental Health Specialists).',
#  'This point of interest is Walmart located at 12353 FM 1960 Rd W, Houston, TX, 77065. It is open for business during { "Mon": [["6:00", "24:00"]], "Tue": [["6:00", "24:00"]], "Wed": [["6:00", "24:00"]], "Thu": [["6:00", "24:00"]], "Fri": [["6:00", "24:00"]], "Sat": [["6:00", "24:00"]], "Sun": [["6:00", "24:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Champions Village located at 5215 FM 1960 Rd W, Houston, TX, 77069. It is open for business during { "Mon": [["7:30", "18:00"]], "Tue": [["7:30", "18:00"]], "Wed": [["7:30", "18:00"]], "Thu": [["7:30", "18:00"]], "Fri": [["7:30", "18:00"]], "Sat": [["8:00", "12:00"]], "Sun": [] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Houston Pavilions located at 1201 Fannin St, Houston, TX, 77002. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Grocery Stores, with sub-category Supermarkets and Other Grocery (except Convenience) Stores.',
#  'This point of interest is Houston Astros located at 501 Crawford St 501 Crawford, Houston, TX, 77002. It is open for business during { "Mon": [["8:30", "17:30"]], "Tue": [["8:30", "17:30"]], "Wed": [["8:30", "17:30"]], "Thu": [["8:30", "17:30"]], "Fri": [["8:30", "17:30"]], "Sat": [], "Sun": [] } and can be contacted by phone at unknown. This location belongs to the top category Other Amusement and Recreation Industries, with sub-category Bowling Centers.',
#  'This point of interest is Walmart located at 2391 S Wayside Dr, Houston, TX, 77023. It is open for business during { "Mon": [["6:00", "24:00"]], "Tue": [["6:00", "24:00"]], "Wed": [["6:00", "24:00"]], "Thu": [["6:00", "24:00"]], "Fri": [["6:00", "24:00"]], "Sat": [["6:00", "24:00"]], "Sun": [["6:00", "24:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Crossroads Plaza located at 13141 FM 1960 Rd W, Houston, TX, 77065. It is open for business during { "Mon": [["10:00", "20:00"]], "Tue": [["10:00", "20:00"]], "Wed": [["10:00", "20:00"]], "Thu": [["10:00", "20:00"]], "Fri": [["10:00", "20:00"]], "Sat": [["9:00", "18:00"]], "Sun": [] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Sterling Plaza located at 9888 Bellaire Blvd, Houston, TX, 77036. It is open for business during { "Mon": [["0:00", "2:00"], ["6:00", "24:00"]], "Tue": [["0:00", "2:00"], ["6:00", "24:00"]], "Wed": [["0:00", "2:00"], ["6:00", "24:00"]], "Thu": [["0:00", "2:00"], ["6:00", "24:00"]], "Fri": [["0:00", "2:00"], ["6:00", "24:00"]], "Sat": [["0:00", "2:00"], ["6:00", "24:00"]], "Sun": [["0:00", "2:00"], ["6:00", "24:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Waterfall Cafe located at Md Anderson Cancer Center Inside Mays Clinic 1155, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Restaurants and Other Eating Places, with sub-category Full-Service Restaurants.',
#  'This point of interest is Walmart located at 13003 State Highway 249, Houston, TX, 77086. It is open for business during { "Mon": [["9:00", "20:00"]], "Tue": [["9:00", "20:00"]], "Wed": [["9:00", "20:00"]], "Thu": [["9:00", "20:00"]], "Fri": [["9:00", "20:00"]], "Sat": [["9:00", "20:00"]], "Sun": [["12:00", "17:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Walmart located at 9598 Rowlett Rd, Houston, TX, 77075. It is open for business during { "Mon": [["7:00", "19:00"]], "Tue": [["7:00", "19:00"]], "Wed": [["7:00", "19:00"]], "Thu": [["7:00", "19:00"]], "Fri": [["7:00", "19:00"]], "Sat": [["7:00", "19:00"]], "Sun": [["8:00", "18:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Costco Wholesale Corp. located at 12405 N Gessner Rd, Houston, TX, 77064. It is open for business during { "Mon": [["10:00", "20:30"]], "Tue": [["10:00", "20:30"]], "Wed": [["10:00", "20:30"]], "Thu": [["10:00", "20:30"]], "Fri": [["10:00", "20:30"]], "Sat": [["9:30", "18:00"]], "Sun": [["10:00", "18:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Walmart located at 10411 North Fwy # 45, Houston, TX, 77037. It is open for business during { "Mon": [["6:00", "24:00"]], "Tue": [["6:00", "24:00"]], "Wed": [["6:00", "24:00"]], "Thu": [["6:00", "24:00"]], "Fri": [["6:00", "24:00"]], "Sat": [["6:00", "24:00"]], "Sun": [["6:00", "24:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Discovery Green located at 1500 McKinney St, Houston, TX, 77010. It is open for business during { "Mon": [["6:00", "23:00"]], "Tue": [["6:00", "23:00"]], "Wed": [["6:00", "23:00"]], "Thu": [["6:00", "23:00"]], "Fri": [["6:00", "23:00"]], "Sat": [["6:00", "23:00"]], "Sun": [["6:00", "23:00"]] } and can be contacted by phone at 17134007336. This location belongs to the top category Museums, Historical Sites, and Similar Institutions, with sub-category Nature Parks and Other Similar Institutions.',
#  'This point of interest is Royal Oaks Village located at 12689 Westheimer Rd, Houston, TX, 77077. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Traders Village located at 7979 N Eldridge Pkwy, Houston, TX, 77041. It is open for business during { "Mon": [], "Tue": [], "Wed": [], "Thu": [], "Fri": [], "Sat": [["9:00", "18:00"]], "Sun": [["9:00", "18:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Student Center Market located at 4455 University Dr University of Houston, Houston, TX, 77004. It is open for business during { "Mon": [["8:00", "21:30"]], "Tue": [["8:00", "21:30"]], "Wed": [["8:00", "21:30"]], "Thu": [["8:00", "21:30"]], "Fri": [["8:00", "17:00"]], "Sat": [["9:00", "20:00"]], "Sun": [["13:00", "20:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Gasoline Stations, with sub-category Gasoline Stations with Convenience Stores.',
#  'This point of interest is Walmart located at 13750 East Fwy, Houston, TX, 77015. It is open for business during { "Mon": [["6:00", "24:00"]], "Tue": [["6:00", "24:00"]], "Wed": [["6:00", "24:00"]], "Thu": [["6:00", "24:00"]], "Fri": [["6:00", "24:00"]], "Sat": [["6:00", "24:00"]], "Sun": [["6:00", "24:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Walmart located at 3506 Highway 6 S, Houston, TX, 77082. It is open for business during { "Mon": [["9:00", "20:00"]], "Tue": [["9:00", "20:00"]], "Wed": [["9:00", "20:00"]], "Thu": [["9:00", "20:00"]], "Fri": [["9:00", "20:00"]], "Sat": [["9:00", "20:00"]], "Sun": [["12:00", "17:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Crossing At Fort Bend Parkway located at 14440 Hillcroft St, Houston, TX, 77085. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Toyota Center located at 1510 Polk St, Houston, TX, 77002. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Spectator Sports, with sub-category Sports Teams and Clubs.',
#  'This point of interest is Clear Lake H S located at 2929 Bay Area Blvd, Houston, TX, 77058. It is open for business during unknown and can be contacted by phone at 12812841900. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is Shops At Houston Center The located at 1200 McKinney St, Houston, TX, 77010. It is open for business during { "Mon": [["9:00", "21:00"]], "Tue": [["9:00", "21:00"]], "Wed": [["9:00", "21:00"]], "Thu": [["9:00", "21:00"]], "Fri": [["9:00", "21:00"]], "Sat": [], "Sun": [] } and can be contacted by phone at 12812302353. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Walmart located at 2727 Dunvale Rd, Houston, TX, 77063. It is open for business during { "Mon": [["7:00", "19:00"]], "Tue": [["7:00", "19:00"]], "Wed": [["7:00", "19:00"]], "Thu": [["7:00", "19:00"]], "Fri": [["7:00", "19:00"]], "Sat": [["7:00", "19:00"]], "Sun": [["8:00", "18:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Four Oaks Place located at 1330 Post Oak Blvd, Houston, TX, 77056. It is open for business during unknown and can be contacted by phone at 17135524803. This location belongs to the top category Museums, Historical Sites, and Similar Institutions, with sub-category Nature Parks and Other Similar Institutions.',
#  'This point of interest is University of Houston Bookstore located at 4800 Calhoun Rd, Houston, TX, 77204. It is open for business during unknown and can be contacted by phone at 17137480923. This location belongs to the top category Book Stores and News Dealers, with sub-category Book Stores.',
#  'This point of interest is Oak Forest Shopping Center located at 1352 W 43rd St, Houston, TX, 77018. It is open for business during { "Mon": [["7:00", "18:00"]], "Tue": [["7:00", "17:00"]], "Wed": [["7:00", "18:00"]], "Thu": [["7:00", "17:00"]], "Fri": [["7:00", "16:00"]], "Sat": [["9:00", "14:00"]], "Sun": [] } and can be contacted by phone at 17134816864. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Plaza On Richmond located at 5177 Richmond Ave, Houston, TX, 77056. It is open for business during unknown and can be contacted by phone at 17139601900. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Hammerly Plaza located at 10110 Hammerly Blvd # 1013, Houston, TX, 77080. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is H-E-B located at 9828 Blackhawk Blvd, Houston, TX, 77075. It is open for business during { "Mon": [["9:00", "21:00"]], "Tue": [["9:00", "21:00"]], "Wed": [["9:00", "21:00"]], "Thu": [["9:00", "21:00"]], "Fri": [["9:00", "21:00"]], "Sat": [["9:00", "18:00"]], "Sun": [["10:00", "17:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Grocery Stores, with sub-category Supermarkets and Other Grocery (except Convenience) Stores.',
#  'This point of interest is River Oaks Plaza located at 1450 W Gray St, Houston, TX, 77019. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Willowbrook Collection located at 17903 Texas 249, Houston, TX, 77070. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Ben Taub General Hospital located at 1504 Taub Lp, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at 17138732000. This location belongs to the top category Continuing Care Retirement Communities and Assisted Living Facilities for the Elderly, with sub-category Assisted Living Facilities for the Elderly.',
#  'This point of interest is Walmart located at 13484 Northwest Fwy, Houston, TX, 77040. It is open for business during { "Mon": [["6:00", "24:00"]], "Tue": [["6:00", "24:00"]], "Wed": [["6:00", "24:00"]], "Thu": [["6:00", "24:00"]], "Fri": [["6:00", "24:00"]], "Sat": [["6:00", "24:00"]], "Sun": [["6:00", "24:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Walmart located at 2700 S Kirkwood Rd, Houston, TX, 77077. It is open for business during { "Mon": [["6:00", "24:00"]], "Tue": [["6:00", "24:00"]], "Wed": [["6:00", "24:00"]], "Thu": [["6:00", "24:00"]], "Fri": [["6:00", "24:00"]], "Sat": [["6:00", "24:00"]], "Sun": [["6:00", "24:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Houston Airport Marriott at George Bush Intercontinental located at 18700 John F Kennedy Blvd, Houston, TX, 77032. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Traveler Accommodation, with sub-category Hotels (except Casino Hotels) and Motels.',
#  'This point of interest is St Agnes Academy School located at 9000 Bellaire Blvd, Houston, TX, 77036. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is Langham Creek Child Care Lab located at 17610 FM 529 Rd, Houston, TX, 77095. It is open for business during unknown and can be contacted by phone at 12818561458. This location belongs to the top category Child Day Care Services, with sub-category Child Day Care Services.',
#  'This point of interest is Beltway 8 located at 9105 W Sam Houston Pkwy N, Houston, TX, 77064. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is BLVD Place located at 1800 Post Oak Blvd Ste 400, Houston, TX, 77056. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Spring Shadows Heb Center & Gessner located at 10243 Kempwood Dr, Houston, TX, 77043. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Almeda Square Shopping Center located at 12152 Gulf Fwy, Houston, TX, 77034. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is St Joseph Medical Center located at 1401 St Joseph Pkwy, Houston, TX, 77002. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category General Medical and Surgical Hospitals, with sub-category General Medical and Surgical Hospitals.',
#  'This point of interest is North Oaks Shopping Center located at 4701 FM 1960 Rd W, Houston, TX, 77069. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Walmart located at 111 Yale St, Houston, TX, 77007. It is open for business during { "Mon": [["9:00", "21:00"]], "Tue": [["9:00", "21:00"]], "Wed": [["9:00", "21:00"]], "Thu": [["9:00", "21:00"]], "Fri": [["9:00", "21:00"]], "Sat": [["9:00", "19:00"]], "Sun": [["10:00", "18:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is West Eight Crossing located at 9050 W Sam Houston Pkwy N, Houston, TX, 77064. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is H-E-B located at 12680 W Lake Houston Pkwy # 8, Houston, TX, 77044. It is open for business during { "Mon": [["6:00", "24:00"]], "Tue": [["6:00", "24:00"]], "Wed": [["6:00", "24:00"]], "Thu": [["6:00", "24:00"]], "Fri": [["6:00", "24:00"]], "Sat": [["6:00", "24:00"]], "Sun": [["6:00", "24:00"]] } and can be contacted by phone at 12814360987. This location belongs to the top category Grocery Stores, with sub-category Supermarkets and Other Grocery (except Convenience) Stores.',
#  'This point of interest is South Cross Center located at 8715 West Loop S, Houston, TX, 77096. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Hilton International located at 1600 Lamar St, Houston, TX, 77010. It is open for business during { "Mon": [["0:00", "24:00"]], "Tue": [["0:00", "24:00"]], "Wed": [["0:00", "24:00"]], "Thu": [["0:00", "24:00"]], "Fri": [["0:00", "24:00"]], "Sat": [["0:00", "24:00"]], "Sun": [["0:00", "24:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Traveler Accommodation, with sub-category Hotels (except Casino Hotels) and Motels.',
#  'This point of interest is Meyer Park Shopping Center located at 4800 W Bellfort St, Houston, TX, 77035. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Walmart located at 10750 Westview Dr, Houston, TX, 77043. It is open for business during { "Mon": [["9:00", "20:00"]], "Tue": [["9:00", "20:00"]], "Wed": [["9:00", "20:00"]], "Thu": [["9:00", "20:00"]], "Fri": [["9:00", "20:00"]], "Sat": [["9:00", "20:00"]], "Sun": [["12:00", "17:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Cumbia Coffee located at 10919 Louetta Rd, Houston, TX, 77070. It is open for business during unknown and can be contacted by phone at 18322573572. This location belongs to the top category Restaurants and Other Eating Places, with sub-category Snack and Nonalcoholic Beverage Bars.',
#  'This point of interest is Beltway South located at 11601 11799 South Sam Houston Parkway East, Houston, TX, 77089. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Market At Hunting Bayou The located at 11430 I 10 East, Houston, TX, 77029. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Baylor College of Medicine Cafeteria located at 1 Baylor Plz, Houston, TX, 77030. It is open for business during unknown and can be contacted by phone at 17137988986. This location belongs to the top category Restaurants and Other Eating Places, with sub-category Full-Service Restaurants.',
#  'This point of interest is River Oaks District located at 4444 Westheimer Rd, Houston, TX, 77027. It is open for business during { "Mon": [["10:00", "19:00"]], "Tue": [["10:00", "19:00"]], "Wed": [["10:00", "19:00"]], "Thu": [["10:00", "19:00"]], "Fri": [["10:00", "19:00"]], "Sat": [["10:00", "19:00"]], "Sun": [["12:00", "18:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Louetta Crossing located at 20608 I 45 North, Houston, TX, 77036. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category unknown, with sub-category unknown.',
#  'This point of interest is San Jacinto Community College North Campus located at 5800 Uvalde Rd, Houston, TX, 77049. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Junior Colleges, with sub-category Junior Colleges.',
#  'This point of interest is Champions Stonebridge located at 6801 FM 1960 Rd W, Houston, TX, 77069. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is H-E-B located at 1550 Fry Rd, Houston, TX, 77084. It is open for business during { "Mon": [["9:00", "21:00"]], "Tue": [["9:00", "21:00"]], "Wed": [["9:00", "21:00"]], "Thu": [["9:00", "21:00"]], "Fri": [["9:00", "21:00"]], "Sat": [["9:00", "18:00"]], "Sun": [["10:00", "17:00"]] } and can be contacted by phone at 12818292565. This location belongs to the top category Grocery Stores, with sub-category Supermarkets and Other Grocery (except Convenience) Stores.',
#  'This point of interest is Walmart located at 5405 S Rice Ave, Houston, TX, 77081. It is open for business during { "Mon": [["8:30", "22:00"]], "Tue": [["8:30", "22:00"]], "Wed": [["8:30", "22:00"]], "Thu": [["8:30", "22:00"]], "Fri": [["8:30", "22:00"]], "Sat": [["8:30", "22:00"]], "Sun": [["9:30", "20:00"]] } and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Westhill Village Shopping Center located at 7601 Westheimer Rd, Houston, TX, 77063. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Walter Oil & Gas located at 1100 Louisiana St Ste 200, Houston, TX, 77002. It is open for business during unknown and can be contacted by phone at 17136591221. This location belongs to the top category Gasoline Stations, with sub-category Gasoline Stations with Convenience Stores.',
#  'This point of interest is Almeda West Shopping Center located at 10150 Almeda Genoa Rd, Houston, TX, 77075. It is open for business during { "Mon": [["8:00", "23:00"]], "Tue": [["8:00", "23:00"]], "Wed": [["8:00", "23:00"]], "Thu": [["8:00", "23:00"]], "Fri": [["8:00", "23:00"]], "Sat": [["8:00", "23:00"]], "Sun": [["9:00", "22:00"]] } and can be contacted by phone at 18328343176. This location belongs to the top category Building Material and Supplies Dealers, with sub-category Paint and Wallpaper Stores.',
# ...
#  'This point of interest is University Plaza located at 2405 Bay Area Blvd, Houston, TX, 77058. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Lakeside Country Club located at 100 Wilcrest Dr, Houston, TX, 77042. It is open for business during unknown and can be contacted by phone at 12814972222. This location belongs to the top category Other Amusement and Recreation Industries, with sub-category Golf Courses and Country Clubs.',
#  'This point of interest is Don McGill Toyota located at 11800 Katy Fwy, Houston, TX, 77079. It is open for business during { "Mon": [["9:00", "21:00"]], "Tue": [["9:00", "21:00"]], "Wed": [["9:00", "21:00"]], "Thu": [["9:00", "21:00"]], "Fri": [["9:00", "21:00"]], "Sat": [["9:00", "21:00"]], "Sun": [] } and can be contacted by phone at 12814962000. This location belongs to the top category Automobile Dealers, with sub-category New Car Dealers.',
#  'This point of interest is The University Of Texas Health Science Center At Houston Mcgovern Medical School located at 6431 Fannin St, Houston, TX, 77030. It is open for business during { "Mon": [["8:00", "17:00"]], "Tue": [["8:00", "17:00"]], "Wed": [["8:00", "17:00"]], "Thu": [["8:00", "17:00"]], "Fri": [["8:00", "17:00"]], "Sat": [], "Sun": [] } and can be contacted by phone at unknown. This location belongs to the top category Colleges, Universities, and Professional Schools, with sub-category Colleges, Universities, and Professional Schools.',
#  'This point of interest is Target located at 4323 San Felipe St, Houston, TX, 77027. It is open for business during { "Mon": [["8:00", "23:59"]], "Tue": [["8:00", "23:59"]], "Wed": [["8:00", "23:59"]], "Thu": [["8:00", "23:59"]], "Fri": [["8:00", "23:59"]], "Sat": [["8:00", "23:59"]], "Sun": [["8:00", "23:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Department Stores, with sub-category Department Stores.',
#  'This point of interest is Joe V\'s Smart Shop located at 12009 Northwest Fwy, Houston, TX, 77092. It is open for business during { "Mon": [["7:00", "22:00"]], "Tue": [["7:00", "22:00"]], "Wed": [["7:00", "22:00"]], "Thu": [["7:00", "22:00"]], "Fri": [["7:00", "22:00"]], "Sat": [["7:00", "22:00"]], "Sun": [["7:00", "22:00"]] } and can be contacted by phone at 17136831720. This location belongs to the top category Grocery Stores, with sub-category Supermarkets and Other Grocery (except Convenience) Stores.',
#  'This point of interest is Reagan H S located at 413 E 13th St, Houston, TX, 77008. It is open for business during unknown and can be contacted by phone at 17138654400. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is Greater Greenspoint North Houston District located at Texas 8 Beltway Frontage Rd, Houston, TX, 77024. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category General Merchandise Stores, including Warehouse Clubs and Supercenters, with sub-category All Other General Merchandise Stores.',
#  'This point of interest is Topgolf located at 1030 Memorial Brook Blvd, Houston, TX, 77084. It is open for business during { "Mon": [["9:00", "23:00"]], "Tue": [["9:00", "23:00"]], "Wed": [["9:00", "23:00"]], "Thu": [["9:00", "23:00"]], "Fri": [["9:00", "24:00"]], "Sat": [["0:00", "1:00"], ["9:00", "24:00"]], "Sun": [["0:00", "1:00"], ["9:00", "23:00"]] } and can be contacted by phone at 12814063176. This location belongs to the top category Other Amusement and Recreation Industries, with sub-category All Other Amusement and Recreation Industries.',
#  'This point of interest is Harris County District Hospital located at 5656 Kelley St, Houston, TX, 77026. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Home Health Care Services, with sub-category Home Health Care Services.',
#  'This point of interest is Lantern Lane Shopping Center located at 12516 Memorial Dr, Houston, TX, 77024. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is South Main Shopping Center located at 12309 12365 South Main Street, Houston, TX, 77035. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Lamar H S located at 3325 Westheimer Rd, Houston, TX, 77098. It is open for business during unknown and can be contacted by phone at 17135225960. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is The Home Depot located at 6800 W Sam Houston Pkwy S, Houston, TX, 77072. It is open for business during { "Mon": [["6:00", "21:00"]], "Tue": [["6:00", "18:00"]], "Wed": [], "Thu": [["6:00", "21:00"]], "Fri": [["6:00", "21:00"]], "Sat": [["6:00", "21:00"]], "Sun": [["8:00", "20:00"]] } and can be contacted by phone at 12814986445. This location belongs to the top category Building Material and Supplies Dealers, with sub-category Hardware Stores.',
#  'This point of interest is The Home Depot located at 14085 Northwest Fwy, Houston, TX, 77040. It is open for business during { "Mon": [["6:00", "21:00"]], "Tue": [["6:00", "18:00"]], "Wed": [], "Thu": [["6:00", "21:00"]], "Fri": [["6:00", "21:00"]], "Sat": [["6:00", "21:00"]], "Sun": [["8:00", "20:00"]] } and can be contacted by phone at 17136906619. This location belongs to the top category Building Material and Supplies Dealers, with sub-category Hardware Stores.',
#  'This point of interest is Pine Forest Shopping Center located at 15 Uvalde Rd, Houston, TX, 77015. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Forest West Shopping Center located at 5375 Antoine Dr, Houston, TX, 77091. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Lifetime Fitness located at 7717 Willow Chase Blvd, Houston, TX, 77070. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Other Amusement and Recreation Industries, with sub-category Fitness and Recreational Sports Centers.',
#  'This point of interest is Einstein Brothers located at 3551 Cullen Blvd, Houston, TX, 77204. It is open for business during unknown and can be contacted by phone at 17137438619. This location belongs to the top category Restaurants and Other Eating Places, with sub-category Limited-Service Restaurants.',
#  'This point of interest is Kroger located at 16400 El Camino Real, Houston, TX, 77062. It is open for business during { "Mon": [["0:00", "1:00"], ["6:00", "24:00"]], "Tue": [["0:00", "1:00"], ["6:00", "24:00"]], "Wed": [["0:00", "1:00"], ["6:00", "24:00"]], "Thu": [["0:00", "1:00"], ["6:00", "24:00"]], "Fri": [["0:00", "1:00"], ["6:00", "24:00"]], "Sat": [["0:00", "1:00"], ["6:00", "24:00"]], "Sun": [["0:00", "1:00"], ["6:00", "24:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Grocery Stores, with sub-category Supermarkets and Other Grocery (except Convenience) Stores.',
#  'This point of interest is Ulrich Int located at 10103 Spring Cypress Rd, Houston, TX, 77070. It is open for business during unknown and can be contacted by phone at 18323757500. This location belongs to the top category Elementary and Secondary Schools, with sub-category Elementary and Secondary Schools.',
#  'This point of interest is West U Marketplace located at 4004 Bellaire Blvd, Houston, TX, 77025. It is open for business during unknown and can be contacted by phone at unknown. This location belongs to the top category Lessors of Real Estate, with sub-category Malls.',
#  'This point of interest is Target located at 300 Meyerland Plaza Mall, Houston, TX, 77096. It is open for business during { "Mon": [["8:00", "23:00"]], "Tue": [["8:00", "23:00"]], "Wed": [["8:00", "23:00"]], "Thu": [["8:00", "23:00"]], "Fri": [["8:00", "23:59"]], "Sat": [["8:00", "23:59"]], "Sun": [["8:00", "23:00"]] } and can be contacted by phone at unknown. This location belongs to the top category Department Stores, with sub-category Department Stores.',
#  'This point of interest is Kroger located at 12222 Jones Rd, Houston, TX, 77070. It is open for business during { "Mon": [["6:00", "24:00"]], "Tue": [["6:00", "24:00"]], "Wed": [["6:00", "24:00"]], "Thu": [["6:00", "24:00"]], "Fri": [["6:00", "24:00"]], "Sat": [["6:00", "24:00"]], "Sun": [["6:00", "24:00"]] } and can be contacted by phone at 18329127474. This location belongs to the top category Grocery Stores, with sub-category Supermarkets and Other Grocery (except Convenience) Stores.',
#  'This point of interest is WEST HOUSTON INFINITI located at 12200 Katy Fwy, Houston, TX, 77079. It is open for business during { "Mon": [["7:00", "20:00"]], "Tue": [["7:00", "20:00"]], "Wed": [["7:00", "20:00"]], "Thu": [["7:00", "20:00"]], "Fri": [["7:00", "20:00"]], "Sat": [["8:00", "18:00"]], "Sun": [] } and can be contacted by phone at 12815898900. This location belongs to the top category Automobile Dealers, with sub-category New Car Dealers.',
#  'This is the meta node that represents all the points of interests in Houston.',
#  'This is the meta node that represents all the points of interests in Houston.',
#  'This is the meta node that represents all the points of interests in Houston.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Amusement Parks and Arcades.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Automobile Dealers.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Automotive Equipment Rental and Leasing.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Book Stores and News Dealers.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Building Material and Supplies Dealers.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Child Day Care Services.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Clothing Stores.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Colleges, Universities, and Professional Schools.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Continuing Care Retirement Communities and Assisted Living Facilities for the Elderly.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Department Stores.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Depository Credit Intermediation.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Educational Support Services.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Elementary and Secondary Schools.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Florists.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Furniture Stores.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Gambling Industries.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Gasoline Stations.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category General Medical and Surgical Hospitals.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category General Merchandise Stores, including Warehouse Clubs and Supercenters.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Grocery Stores.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Health and Personal Care Stores.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Home Health Care Services.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Jewelry, Luggage, and Leather Goods Stores.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Junior Colleges.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Justice, Public Order, and Safety Activities.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Lessors of Real Estate.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Motion Picture and Video Industries.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Museums, Historical Sites, and Similar Institutions.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Office Supplies, Stationery, and Gift Stores.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Offices of Physicians.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Other Amusement and Recreation Industries.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Other Information Services.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Other Miscellaneous Manufacturing.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Personal Care Services.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category RV (Recreational Vehicle) Parks and Recreational Camps.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Restaurants and Other Eating Places.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Specialty Food Stores.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Spectator Sports.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Sporting Goods, Hobby, and Musical Instrument Stores.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Support Activities for Air Transportation.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Technical and Trade Schools.',
#  'This is the meta node that represents all the points of interests in Houston that belong to the category Traveler Accommodation.']

# %%
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
embeddings = model.encode(sentences)
embeddings.shape
# Out:
# (445, 768)

# %%
(embeddings[93] * embeddings[296]).sum()
# Out:
# 0.60260606
